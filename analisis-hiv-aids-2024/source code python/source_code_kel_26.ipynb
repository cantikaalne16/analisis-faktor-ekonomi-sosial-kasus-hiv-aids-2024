# %% [markdown]
# #**PROJECT AKHIR DATA WRANGLING**
#
# ##**Analisis Faktor Sosial Ekonomi terhadap Kasus HIV & AIDS di Indonesia Tahun 2024**
#
# ###Dosen Pengampu = Bu Ulfa Siti Nuraini, S.Stat., M.Stat.
#
# ####Disusun oleh:
# ####1. Adisti Eka Nabila (24031554119)
# ####2. Cantika Latifatul Nur Ella (24031554023)

# %% [markdown]
# ##**1. SCRAPPING**

# %%
# !pip install PyMupdf
# Out:
# Collecting PyMupdf
#   Downloading pymupdf-1.26.6-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.26.6-cp310-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 33.4 MB/s eta 0:00:00
# Installing collected packages: PyMupdf
# Successfully installed PyMupdf-1.26.6

# %%
# !pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.8-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.9 MB/s eta 0:00:00
# Collecting pdfminer.six==20251107 (from pdfplumber)
#   Downloading pdfminer_six-20251107-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.12/dist-packages (from pdfplumber) (11.3.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-5.1.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251107->pdfplumber) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251107->pdfplumber) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber) (2.23)
# Downloading pdfplumber-0.11.8-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 2.6 MB/s eta 0:00:00
# Downloading pdfminer_six-20251107-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 45.2 MB/s eta 0:00:00
# Downloading pypdfium2-5.1.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 102.4 MB/s eta 0:00:00
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20251107 pdfplumber-0.11.8 pypdfium2-5.1.0

# %%
# !pip install tabula-py
# Out:
# Collecting tabula-py
#   Downloading tabula_py-2.10.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.12/dist-packages (from tabula-py) (2.2.2)
# Requirement already satisfied: numpy>1.24.4 in /usr/local/lib/python3.12/dist-packages (from tabula-py) (2.0.2)
# Requirement already satisfied: distro in /usr/local/lib/python3.12/dist-packages (from tabula-py) (1.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.25.3->tabula-py) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.25.3->tabula-py) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.25.3->tabula-py) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.25.3->tabula-py) (1.17.0)
# Downloading tabula_py-2.10.0-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 21.1 MB/s eta 0:00:00
# Installing collected packages: tabula-py
# Successfully installed tabula-py-2.10.0

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.12/dist-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.12/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob
import os
import fitz
import pandas as pd
import tabula
import pdfplumber
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(os.listdir('/content/drive/Shared drives/Project Data Wrangling/'))
# Out:
# ['Profil Kesehatan Indonesia 2024.pdf', 'Tingkat Pengangguran 2024.csv', 'Rata Rata Lama Sekolah 2024.csv', 'Profile Kemiskinan di Indonesia.pdf']

# %%
pdf_hiv_aids = "/content/drive/Shared drives/Project Data Wrangling/Profil Kesehatan Indonesia 2024.pdf"

# %%
doc1 = fitz.open(pdf_hiv_aids)
doc1
# Out:
# Document('/content/drive/Shared drives/Project Data Wrangling/Profil Kesehatan Indonesia 2024.pdf')

# %%
doc1.metadata
# Out:
# {'format': 'PDF 1.5',
#  'title': '',
#  'author': '',
#  'subject': '',
#  'keywords': '',
#  'creator': 'Adobe InDesign 15.1 (Macintosh)',
#  'producer': 'Adobe PDF Library 15.0',
#  'creationDate': "D:20250908122302+07'00'",
#  'modDate': "D:20250908123409+07'00'",
#  'trapped': '',
#  'encryption': None}

# %%
print('Number of pages: ', doc1.page_count)
# Out:
# Number of pages:  534

# %%
page = doc1[3].get_text()
print(page)
# Out:
# Buku ini diterbitkan oleh:
# Kementerian Kesehatan Republik Indonesia
# Jalan HR. Rasuna Said Blok X-5 Kav 4-9, Jakarta 12950
# Telepon no: 62-21-5229590, 5221432, 5277168
# Fax no: 62-21-5277168
# E-mail: datainformasi.pusdatin@kemkes.go.id
# Website: http://www.kemkes/go.id
# Katalog Dalam Terbitan. Kementerian Kesehatan RI
# Indonesia. Kementerian Kesehatan RI. Sekretariat Jenderal
# Profil Kesehatan Indonesia 2023.
# Jakarta: Kementerian Kesehatan RI. 2024
# 1. Judul            I. HEALTH STATISTICS
# II. HEALTH INFORMATION SYSTEMS
# 000.000
# Ind
# p

# %% [markdown]
# ###DATA HIV

# %%
tables = tabula.read_pdf(
    pdf_hiv_aids,
    pages=472,
    multiple_tables=True,
    lattice=True
)
scrape_hiv_df = tables[0]
# Out:
# WARNING:tabula.backend:Failed to import jpype dependencies. Fallback to subprocess.
# WARNING:tabula.backend:No module named 'jpype'

# %%
scrape_hiv_df.head(7)
# Out:
#     No        Provinsi Jumlah Kasus Baru HIV Unnamed: 0 Unnamed: 1
# 0  NaN             NaN                  2022       2023       2024
# 1  (1)             (2)                   (3)        (4)        (5)
# 2    1            Aceh                   269        279        352
# 3    2  Sumatera Utara                 2.777      3.105      3.250
# 4    3  Sumatera Barat                   526        579        654
# 5    4            Riau                   766        914      1.007
# 6    5           Jambi                   182        261        313

# %%
scrape_hiv_df.to_csv("scrape_hiv_raw.csv", index=False)

# %% [markdown]
# ###DATA AIDS

# %%
tables = tabula.read_pdf(
    pdf_hiv_aids,
    pages=475,
    multiple_tables=True,
    lattice=True
)

scrape_aids_df = tables[0]

# %%
scrape_aids_df.head(7)
# Out:
#     No        Provinsi Jumlah Kasus Baru  \
# 0  NaN             NaN              2022
# 1  (1)             (2)               (3)
# 2    1            Aceh                33
# 3    2  Sumatera Utara               403
# 4    3  Sumatera Barat               109
# 5    4            Riau               223
# 6    5           Jambi                21
#
#   Jumlah Kasus Kumulatif\rs.d. Desember 2024 Unnamed: 0 Unnamed: 1
# 0                                       2023       2024        NaN
# 1                                        (4)        (5)        (6)
# 2                                         88        130        NaN
# 3                                        893      1.316        NaN
# 4                                        156        238        NaN
# 5                                        263        345        NaN
# 6                                         36         93        NaN

# %%
scrape_aids_df.to_csv("scrape_aids_raw.csv", index=False)

# %% [markdown]
# ###DATA KEMISKINAN

# %%
pdf_kemiskinan = '/content/drive/Shared drives/Project Data Wrangling/Profile Kemiskinan di Indonesia.pdf'

# %%
doc2 = fitz.open(pdf_kemiskinan)
doc2
# Out:
# Document('/content/drive/Shared drives/Project Data Wrangling/Profile Kemiskinan di Indonesia.pdf')

# %%
print('Number of page', doc2.page_count)
# Out:
# Number of page 16

# %%
data = []
with pdfplumber.open(pdf_kemiskinan) as pdf:
    page = pdf.pages[9]
    table = page.extract_table()
    df = pd.DataFrame(table[1:], columns=table[0])
    data.append(df)

scrape_kemiskinan_df = pd.concat(data, ignore_index=True)

# %%
scrape_kemiskinan_df.head(7)
# Out:
#   Provinsi            None Jumlah Penduduk Miskin (ribu)    None       None  \
# 0     None            None                     Perkotaan    None  Perdesaan
# 1     None            None                        Mar’24  Sep’24     Mar’24
# 2      (1)            None                           (2)     (3)        (4)
# 3       1.            Aceh                        190,55  168,71     613,98
# 4       2.  Sumatera Utara                        697,46  623,78     530,55
# 5       3.  Sumatera Barat                        139,12  125,69     206,62
# 6       4.            Riau                        200,91  183,28     291,34
#
#      None      None      None
# 0    None     Total      None
# 1  Sep’24    Mar’24    Sep’24
# 2     (5)       (6)       (7)
# 3  550,25    804,53    718,96
# 4  487,14  1.228,01  1.110,92
# 5  189,75    345,73    315,43
# 6  289,76    492,25    473,04

# %%
scrape_kemiskinan_df.to_csv("scrape_kemiskinan_raw.csv", index=False)

# %% [markdown]
# ##**2. CLEANING & INTEGRASI**

# %% [markdown]
# ###DATA HIV

# %%
df1 = scrape_hiv_df

df1.columns = ["No", "Provinsi", "2022", "2023", "2024"]

df1 = df1.iloc[2:]
df1 = df1.iloc[:-1]

df1 = df1[["Provinsi", "2024"]]

df1.rename(columns={"2024": "Kasus HIV 2024"}, inplace=True)

df1["Kasus HIV 2024"] = df1["Kasus HIV 2024"].str.replace(".", "", regex=False).astype(int)
df1_hiv = df1.reset_index(drop=True)

# %%
df1_hiv.head(7)
# Out:
#            Provinsi  Kasus HIV 2024
# 0              Aceh             352
# 1    Sumatera Utara            3250
# 2    Sumatera Barat             654
# 3              Riau            1007
# 4             Jambi             313
# 5  Sumatera Selatan             986
# 6          Bengkulu             173

# %%
df1_hiv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Provinsi        38 non-null     object
#  1   Kasus HIV 2024  38 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 740.0+ bytes

# %%
df1_hiv['Provinsi'] = df1_hiv['Provinsi'].str.upper()
df1_hiv.head(7)
# Out:
#            Provinsi  Kasus HIV 2024
# 0              ACEH             352
# 1    SUMATERA UTARA            3250
# 2    SUMATERA BARAT             654
# 3              RIAU            1007
# 4             JAMBI             313
# 5  SUMATERA SELATAN             986
# 6          BENGKULU             173

# %%
df1_hiv.isna().sum()
# Out:
# Provinsi          0
# Kasus HIV 2024    0
# dtype: int64

# %%
df1.to_csv("data_hiv_clean.csv", index=False)

# %% [markdown]
# ###DATA AIDS

# %%
df2 = scrape_aids_df

df2.columns = ["No", "Provinsi", "2022", "2023", "2024", "Kasus_Kumulatif"]

df2 = df2.iloc[2:]
df2 = df2.iloc[:-1]

df2 = df2[["Provinsi", "2024"]]

df2.rename(columns={"2024": "Kasus AIDS 2024"}, inplace=True)

df2["Kasus AIDS 2024"] = df2["Kasus AIDS 2024"].str.replace(".", "", regex=False).astype(int)
df2_aids = df2.reset_index(drop=True)

# %%
df2_aids.head(7)
# Out:
#            Provinsi  Kasus AIDS 2024
# 0              Aceh              130
# 1    Sumatera Utara             1316
# 2    Sumatera Barat              238
# 3              Riau              345
# 4             Jambi               93
# 5  Sumatera Selatan              332
# 6          Bengkulu               57

# %%
df2_aids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Provinsi         38 non-null     object
#  1   Kasus AIDS 2024  38 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 740.0+ bytes

# %%
df2_aids['Provinsi'] = df2_aids['Provinsi'].str.upper()
df2_aids.head(7)
# Out:
#            Provinsi  Kasus AIDS 2024
# 0              ACEH              130
# 1    SUMATERA UTARA             1316
# 2    SUMATERA BARAT              238
# 3              RIAU              345
# 4             JAMBI               93
# 5  SUMATERA SELATAN              332
# 6          BENGKULU               57

# %%
df2_aids.isna().sum()
# Out:
# Provinsi           0
# Kasus AIDS 2024    0
# dtype: int64

# %%
df2.to_csv("data_aids_clean.csv", index=False)

# %% [markdown]
# ###DATA KEMISKINAN

# %%
df3 = scrape_kemiskinan_df

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Provinsi                       40 non-null     object
#  1   None                           38 non-null     object
#  2   Jumlah Penduduk Miskin (ribu)  42 non-null     object
#  3   None                           41 non-null     object
#  4   None                           42 non-null     object
#  5   None                           41 non-null     object
#  6   None                           42 non-null     object
#  7   None                           41 non-null     object
# dtypes: object(8)
# memory usage: 2.8+ KB

# %%
missing=df3[df3["Provinsi"].isna()]
missing.head()
# Out:
#   Provinsi  None Jumlah Penduduk Miskin (ribu)    None       None    None  \
# 0     None  None                     Perkotaan    None  Perdesaan    None
# 1     None  None                        Mar’24  Sep’24     Mar’24  Sep’24
#
#      None    None
# 0   Total    None
# 1  Mar’24  Sep’24

# %%
df3 = df3.drop(index=[0,1,2]).reset_index(drop=True)
df3 = df3.iloc[:-1].reset_index(drop=True)

# %%
df3.columns = ["No", "Provinsi", "Perkotaan Mar'24", "perkotaan Sep'24", "Perdesaan Mar'24", "Perdesaan sep'24", "Total Mar'24", "Jumlah penduduk miskin (Ribu)"]
df3.columns.tolist()
# Out:
# ['No',
#  'Provinsi',
#  "Perkotaan Mar'24",
#  "perkotaan Sep'24",
#  "Perdesaan Mar'24",
#  "Perdesaan sep'24",
#  "Total Mar'24",
#  'Jumlah penduduk miskin (Ribu)']

# %%
df3_kemiskinan = df3[["Provinsi","Jumlah penduduk miskin (Ribu)"]]
df3_kemiskinan= df3_kemiskinan.replace("\n", " ", regex=True)
df3_kemiskinan.head(7)
# Out:
#            Provinsi Jumlah penduduk miskin (Ribu)
# 0              Aceh                        718,96
# 1    Sumatera Utara                      1.110,92
# 2    Sumatera Barat                        315,43
# 3              Riau                        473,04
# 4             Jambi                        272,70
# 5  Sumatera Selatan                        948,84
# 6          Bengkulu                        261,15

# %%
df3_kemiskinan["Jumlah penduduk miskin (Ribu)"] = (
    df3_kemiskinan["Jumlah penduduk miskin (Ribu)"]
    .astype(str)
    .str.replace('.', '', regex=False)
    .str.replace(',', '.', regex=False)
    .pipe(pd.to_numeric, errors='coerce')
)

# %%
df3_kemiskinan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Provinsi                       38 non-null     object
#  1   Jumlah penduduk miskin (Ribu)  38 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 740.0+ bytes

# %%
df3_kemiskinan["Provinsi"] = df3_kemiskinan["Provinsi"].str.upper().str.strip()
df3_kemiskinan.head(7)
# Out:
#            Provinsi  Jumlah penduduk miskin (Ribu)
# 0              ACEH                         718.96
# 1    SUMATERA UTARA                        1110.92
# 2    SUMATERA BARAT                         315.43
# 3              RIAU                         473.04
# 4             JAMBI                         272.70
# 5  SUMATERA SELATAN                         948.84
# 6          BENGKULU                         261.15

# %%
df3_kemiskinan.isna().sum()
# Out:
# Provinsi                         0
# Jumlah penduduk miskin (Ribu)    0
# dtype: int64

# %%
df3.to_csv("data_kemiskinan_clean.csv", index=False)

# %% [markdown]
# ###DATA PENGANGGURAN

# %%
csv_pengangguran = '/content/drive/Shared drives/Project Data Wrangling/Tingkat Pengangguran 2024.csv'

# %%
df4 = pd.read_csv(csv_pengangguran)

df4_pengangguran = df4[["nama_provinsi", "indeks_tpt"]]

# %%
df4_pengangguran.head(7)
# Out:
#       nama_provinsi  indeks_tpt
# 0              ACEH        5.75
# 1    SUMATERA UTARA        5.60
# 2    SUMATERA BARAT        5.75
# 3              RIAU        3.70
# 4             JAMBI        4.48
# 5  SUMATERA SELATAN        3.86
# 6          BENGKULU        3.11

# %%
df4_pengangguran.columns = ["Provinsi", "Indeks TPT (%)"]
df4_pengangguran.columns.tolist()
# Out:
# ['Provinsi', 'Indeks TPT (%)']

# %%
df4_pengangguran.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Provinsi        38 non-null     object
#  1   Indeks TPT (%)  38 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 740.0+ bytes

# %%
df4_pengangguran.head(7)
# Out:
#            Provinsi  Indeks TPT (%)
# 0              ACEH            5.75
# 1    SUMATERA UTARA            5.60
# 2    SUMATERA BARAT            5.75
# 3              RIAU            3.70
# 4             JAMBI            4.48
# 5  SUMATERA SELATAN            3.86
# 6          BENGKULU            3.11

# %%
df4_pengangguran.isna().sum()
# Out:
# Provinsi          0
# Indeks TPT (%)    0
# dtype: int64

# %%
df4_pengangguran.to_csv("data_pengangguran_clean.csv", index=False)

# %% [markdown]
# ###DATA RATA" LAMA SEKOLAH

# %%
csv_rata_lama_sekolah = '/content/drive/Shared drives/Project Data Wrangling/Rata Rata Lama Sekolah 2024.csv'

# %%
df5 = pd.read_csv(csv_rata_lama_sekolah)
df5.head()
# Out:
#   Provinsi/Kabupaten/Kota                                    Unnamed: 1
# 0                     NaN  [Metode Baru] Rata-rata Lama Sekolah (Tahun)
# 1                     NaN                                          2024
# 2                    ACEH                                          9.64
# 3                Simeulue                                          9.89
# 4            Aceh Singkil                                          8.72

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 581 entries, 0 to 580
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Provinsi/Kabupaten/Kota  579 non-null    object
#  1   Unnamed: 1               581 non-null    object
# dtypes: object(2)
# memory usage: 9.2+ KB

# %%
missing=df5[df5["Provinsi/Kabupaten/Kota"].isna()]
missing.head()
# Out:
#   Provinsi/Kabupaten/Kota                                    Unnamed: 1
# 0                     NaN  [Metode Baru] Rata-rata Lama Sekolah (Tahun)
# 1                     NaN                                          2024

# %%
df5 = df5.dropna(subset=["Provinsi/Kabupaten/Kota"]).reset_index(drop=True)

# %%
df5 = df5.iloc[:-1].reset_index(drop=True)

# %%
df5["Provinsi/Kabupaten/Kota"] = df5["Provinsi/Kabupaten/Kota"].str.replace("D I YOGYAKARTA", "DI YOGYAKARTA")
df5["Provinsi/Kabupaten/Kota"] = df5["Provinsi/Kabupaten/Kota"].str.replace("KEP. BANGKA BELITUNG", "KEPULAUAN BANGKA BELITUNG")

# %%
df5.columns = ["Provinsi","Rata-rata Lama Sekolah (Tahun)"]
df5.columns.tolist()
# Out:
# ['Provinsi', 'Rata-rata Lama Sekolah (Tahun)']

# %%
df5["Rata-rata Lama Sekolah (Tahun)"] = pd.to_numeric(df5["Rata-rata Lama Sekolah (Tahun)"], errors="coerce")
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578 entries, 0 to 577
# Data columns (total 2 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Provinsi                        578 non-null    object
#  1   Rata-rata Lama Sekolah (Tahun)  552 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 9.2+ KB

# %%
df5_sekolah = df5[["Provinsi", "Rata-rata Lama Sekolah (Tahun)"]]
df5_sekolah
# Out:
#                Provinsi  Rata-rata Lama Sekolah (Tahun)
# 0                  ACEH                            9.64
# 1              Simeulue                            9.89
# 2          Aceh Singkil                            8.72
# 3          Aceh Selatan                            8.92
# 4         Aceh Tenggara                           10.10
# ..                  ...                             ...
# 573            Tolikara                            3.69
# 574    Mamberamo Tengah                            3.70
# 575              Yalimo                            3.55
# 576            Yahukimo                            4.35
# 577  Pegunungan Bintang                            3.51
#
# [578 rows x 2 columns]

# %%
df5_sekolah = df5_sekolah[df5_sekolah["Provinsi"].str.isupper()].reset_index(drop=True)

# %%
df5_sekolah["Provinsi"] = df5_sekolah["Provinsi"].str.upper().str.strip()
df5_sekolah.head(7)
# Out:
#            Provinsi  Rata-rata Lama Sekolah (Tahun)
# 0              ACEH                            9.64
# 1    SUMATERA UTARA                            9.93
# 2    SUMATERA BARAT                            9.44
# 3              RIAU                            9.43
# 4             JAMBI                            8.90
# 5  SUMATERA SELATAN                            8.57
# 6          BENGKULU                            9.04

# %%
df5_sekolah.isna().sum()
# Out:
# Provinsi                          0
# Rata-rata Lama Sekolah (Tahun)    0
# dtype: int64

# %%
df5.to_csv("data_lama_sekolah_clean.csv", index=False)

# %% [markdown]
# ###INTEGRASI BESAR

# %%
sort_prov = df3_kemiskinan["Provinsi"].tolist()

# %%
df_merge = (
    df3_kemiskinan
    .merge(df5_sekolah, on="Provinsi", how="outer")
    .merge(df4_pengangguran, on="Provinsi", how="outer")
    .merge(df1_hiv, on="Provinsi", how="outer")
    .merge(df2_aids, on="Provinsi", how="outer")
)

# %%
import pandas as pd

df_merge["Provinsi"] = pd.Categorical(
    df_merge["Provinsi"],
    categories=sort_prov,
    ordered=True
)

# %%
df_merge = df_merge.sort_values("Provinsi").reset_index(drop=True)

# %%
df_merge
# Out:
#                      Provinsi  Jumlah penduduk miskin (Ribu)  \
# 0                        ACEH                         718.96
# 1              SUMATERA UTARA                        1110.92
# 2              SUMATERA BARAT                         315.43
# 3                        RIAU                         473.04
# 4                       JAMBI                         272.70
# 5            SUMATERA SELATAN                         948.84
# 6                    BENGKULU                         261.15
# 7                     LAMPUNG                         939.30
# 8   KEPULAUAN BANGKA BELITUNG                          78.58
# 9              KEPULAUAN RIAU                         124.96
# 10                DKI JAKARTA                         449.07
# 11                 JAWA BARAT                        3668.35
# 12                JAWA TENGAH                        3396.34
# 13              DI YOGYAKARTA                         430.47
# 14                 JAWA TIMUR                        3893.82
# 15                     BANTEN                         777.49
# 16                       BALI                         176.21
# 17        NUSA TENGGARA BARAT                         658.60
# 18        NUSA TENGGARA TIMUR                        1107.94
# 19           KALIMANTAN BARAT                         333.99
# 20          KALIMANTAN TENGAH                         149.24
# 21         KALIMANTAN SELATAN                         180.20
# 22           KALIMANTAN TIMUR                         211.88
# 23           KALIMANTAN UTARA                          41.11
# 24             SULAWESI UTARA                         173.30
# 25            SULAWESI TENGAH                         358.33
# 26           SULAWESI SELATAN                         711.77
# 27          SULAWESI TENGGARA                         305.27
# 28                  GORONTALO                         170.03
# 29             SULAWESI BARAT                         155.91
# 30                     MALUKU                         293.99
# 31               MALUKU UTARA                          79.69
# 32                PAPUA BARAT                         108.28
# 33           PAPUA BARAT DAYA                          96.81
# 34                      PAPUA                         161.07
# 35              PAPUA SELATAN                         103.02
# 36               PAPUA TENGAH                         287.54
# 37           PAPUA PEGUNUNGAN                         331.12
#
#     Rata-rata Lama Sekolah (Tahun)  Indeks TPT (%)  Kasus HIV 2024  \
# 0                             9.64            5.75             352
# 1                             9.93            5.60            3250
# 2                             9.44            5.75             654
# 3                             9.43            3.70            1007
# 4                             8.90            4.48             313
# 5                             8.57            3.86             986
# 6                             9.04            3.11             173
# 7                             8.36            4.19            1220
# 8                             8.33            4.63             277
# 9                            10.50            6.39             949
# 10                           11.49            6.21            5027
# 11                            8.87            6.75            9893
# 12                            8.02            4.78            6191
# 13                            9.92            3.48             928
# 14                            8.28            4.19           10460
# 15                            9.23            6.68            2434
# 16                            9.54            1.79            1998
# 17                            7.87            2.73             627
# 18                            8.02            3.02            1255
# 19                            7.78            4.86            1309
# 20                            8.81            4.01             485
# 21                            8.62            4.20             674
# 22                           10.02            5.14            1375
# 23                            9.35            3.90             209
# 24                            9.84            5.85             869
# 25                            9.04            2.94             705
# 26                            8.86            4.19            2120
# 27                            9.42            3.09             646
# 28                            8.29            3.13             277
# 29                            8.15            2.68             134
# 30                           10.26            6.11             861
# 31                            9.37            4.03             592
# 32                            7.86            4.13             827
# 33                            8.39            6.48             291
# 34                            9.82            6.48            2275
# 35                            8.38            4.05             194
# 36                            6.12            2.75            1311
# 37                            4.21            1.32             559
#
#     Kasus AIDS 2024
# 0               130
# 1              1316
# 2               238
# 3               345
# 4                93
# 5               332
# 6                57
# 7               351
# 8                84
# 9               352
# 10             1820
# 11             3239
# 12             2058
# 13              250
# 14             3713
# 15              711
# 16              779
# 17              189
# 18              465
# 19              415
# 20              192
# 21              256
# 22              389
# 23               86
# 24              312
# 25              261
# 26              741
# 27              196
# 28               90
# 29               56
# 30              189
# 31              223
# 32              184
# 33               97
# 34              819
# 35               75
# 36              433
# 37                0

# %%
df_merge.to_csv("DATA FINAL.csv", index=False)

# %% [markdown]
# ##**3. EDA (Exploratory Data Analysis)**

# %% [markdown]
# ####Cek Missing Values

# %%
df_merge.isna().sum()
# Out:
# Provinsi                          0
# Jumlah penduduk miskin (Ribu)     0
# Rata-rata Lama Sekolah (Tahun)    0
# Indeks TPT (%)                    0
# Kasus HIV 2024                    0
# Kasus AIDS 2024                   0
# dtype: int64

# %% [markdown]
# ###Cek Duplicate

# %%
df_merge.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ###Cek Tipe Data

# %%
df_merge.dtypes
# Out:
# Provinsi                          category
# Jumlah penduduk miskin (Ribu)      float64
# Rata-rata Lama Sekolah (Tahun)     float64
# Indeks TPT (%)                     float64
# Kasus HIV 2024                       int64
# Kasus AIDS 2024                      int64
# dtype: object

# %% [markdown]
# ###Cek Statistik Deskriptif

# %%
df_merge.describe()
# Out:
#        Jumlah penduduk miskin (Ribu)  Rata-rata Lama Sekolah (Tahun)  \
# count                      38.000000                       38.000000
# mean                      633.018947                        8.841316
# std                       944.382913                        1.227811
# min                        41.110000                        4.210000
# 25%                       163.310000                        8.300000
# 50%                       299.630000                        8.885000
# 75%                       698.477500                        9.515000
# max                      3893.820000                       11.490000
#
#        Indeks TPT (%)  Kasus HIV 2024  Kasus AIDS 2024
# count       38.000000       38.000000        38.000000
# mean         4.379737     1676.500000       566.736842
# std          1.414222     2394.915208       830.786917
# min          1.320000      134.000000         0.000000
# 25%          3.217500      503.500000       143.500000
# 50%          4.190000      865.000000       258.500000
# 75%          5.712500     1359.000000       457.000000
# max          6.750000    10460.000000      3713.000000

# %% [markdown]
# ###Finding Outlier

# %%
df6 = df_merge
num_cols = [
    "Jumlah penduduk miskin (Ribu)",
    "Rata-rata Lama Sekolah (Tahun)",
    "Indeks TPT (%)",
    "Kasus HIV 2024",
    "Kasus AIDS 2024"
]

df_num = df6[num_cols]
Q1 = df_num.quantile(0.25)
Q3 = df_num.quantile(0.75)
IQR = Q3 - Q1


lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
outlier_mask = (df_num < lower) | (df_num > upper)
outliers = df6[outlier_mask.any(axis=1)]


print("Outliers detected (per provinsi)")
print(outliers)


print("\nOutlier Boundaries (per variabel)")
print(pd.DataFrame({
    "Lower Bound": lower,
    "Upper Bound": upper
}))
# Out:
# Outliers detected (per provinsi)
#             Provinsi  Jumlah penduduk miskin (Ribu)  \
# 1     SUMATERA UTARA                        1110.92
# 10       DKI JAKARTA                         449.07
# 11        JAWA BARAT                        3668.35
# 12       JAWA TENGAH                        3396.34
# 14        JAWA TIMUR                        3893.82
# 36      PAPUA TENGAH                         287.54
# 37  PAPUA PEGUNUNGAN                         331.12
#
#     Rata-rata Lama Sekolah (Tahun)  Indeks TPT (%)  Kasus HIV 2024  \
# 1                             9.93            5.60            3250
# 10                           11.49            6.21            5027
# 11                            8.87            6.75            9893
# 12                            8.02            4.78            6191
# 14                            8.28            4.19           10460
# 36                            6.12            2.75            1311
# 37                            4.21            1.32             559
#
#     Kasus AIDS 2024
# 1              1316
# 10             1820
# 11             3239
# 12             2058
# 14             3713
# 36              433
# 37                0
#
# Outlier Boundaries (per variabel)
#                                 Lower Bound  Upper Bound
# Jumlah penduduk miskin (Ribu)    -639.44125   1501.22875
# Rata-rata Lama Sekolah (Tahun)      6.47750     11.33750
# Indeks TPT (%)                     -0.52500      9.45500
# Kasus HIV 2024                   -779.75000   2642.25000
# Kasus AIDS 2024                  -326.75000    927.25000

# %%
df_num = df6[[
    "Jumlah penduduk miskin (Ribu)",
    "Rata-rata Lama Sekolah (Tahun)",
    "Indeks TPT (%)",
    "Kasus HIV 2024",
    "Kasus AIDS 2024"
]]

plt.figure(figsize=(10, 8))

sns.boxplot(data=df_num)

plt.title("Boxplot untuk Deteksi Outlier")
plt.xticks(rotation=35)
plt.tight_layout()

plt.savefig("boxplot_sosialekonomi_hivaids.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ###Rasio Kasus HIV & AIDS

# %%
rasio_values = []

for hiv, aids in zip(df_merge["Kasus HIV 2024"], df_merge["Kasus AIDS 2024"]):
    if aids == 0:
        rasio_values.append(0)
    else:
        rasio_values.append(hiv / aids)

df_merge["Rasio HIV AIDS"] = rasio_values

# %%
df_merge[["Provinsi", "Rasio HIV AIDS"]].head(7)
# Out:
#            Provinsi  Rasio HIV AIDS
# 0              ACEH        2.707692
# 1    SUMATERA UTARA        2.469605
# 2    SUMATERA BARAT        2.747899
# 3              RIAU        2.918841
# 4             JAMBI        3.365591
# 5  SUMATERA SELATAN        2.969880
# 6          BENGKULU        3.035088

# %%
df_sorted = df_merge.sort_values(by="Rasio HIV AIDS", ascending=False).head(10)

plt.figure(figsize=(7,5))
plt.bar(df_sorted["Provinsi"], df_sorted["Rasio HIV AIDS"])

plt.xlabel("Provinsi")
plt.ylabel("Rasio HIV AIDS")
plt.title("Rasio HIV AIDS per Provinsi (Tertinggi ke Terendah)")

for i, v in enumerate(df_sorted["Rasio HIV AIDS"]):
    plt.text(i, v + 0.025, f"{v:.2f}", ha='center', fontsize=8)

plt.xticks(rotation=90)
plt.tight_layout()

plt.savefig("barplot_rasio_hivaids.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ###HeatMap

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df_merge.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Korelasi Faktor Sosial Ekonomi terhadap HIV/AIDS")
plt.savefig("heatmap_sosialekonomi_hivaids.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ###Scatter Plot

# %%
fig, axes = plt.subplots(2, 3, figsize=(28, 18))

targets = ["Kasus HIV 2024", "Kasus AIDS 2024"]
features = ["Jumlah penduduk miskin (Ribu)", "Rata-rata Lama Sekolah (Tahun)", "Indeks TPT (%)"]

for row, target in enumerate(targets):
    for col, feature in enumerate(features):

        ax = axes[row, col]

        sns.regplot(
            ax=ax,
            data=df_merge,
            x=feature,
            y=target,
            scatter_kws={"s": 80}
        )

        ax.set_title(f"{feature} vs {target}", fontsize=14)
        ax.set_xlabel(feature, fontsize=12)
        ax.set_ylabel(target, fontsize=12)

        for i in range(len(df_merge)):
            ax.text(
                df_merge[feature].iloc[i],
                df_merge[target].iloc[i],
                str(df_merge.index[i]),
                fontsize=12,
                alpha=0.8
            )

plt.tight_layout()
plt.savefig("scatterplot_sosialekonomi_hivaids.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ###Peringkat Faktor Sosial-Ekonomi

# %%
df_merge.sort_values("Jumlah penduduk miskin (Ribu)", ascending=False).head(10)
# Out:
#                Provinsi  Jumlah penduduk miskin (Ribu)  \
# 14           JAWA TIMUR                        3893.82
# 11           JAWA BARAT                        3668.35
# 12          JAWA TENGAH                        3396.34
# 1        SUMATERA UTARA                        1110.92
# 18  NUSA TENGGARA TIMUR                        1107.94
# 5      SUMATERA SELATAN                         948.84
# 7               LAMPUNG                         939.30
# 15               BANTEN                         777.49
# 0                  ACEH                         718.96
# 26     SULAWESI SELATAN                         711.77
#
#     Rata-rata Lama Sekolah (Tahun)  Indeks TPT (%)  Kasus HIV 2024  \
# 14                            8.28            4.19           10460
# 11                            8.87            6.75            9893
# 12                            8.02            4.78            6191
# 1                             9.93            5.60            3250
# 18                            8.02            3.02            1255
# 5                             8.57            3.86             986
# 7                             8.36            4.19            1220
# 15                            9.23            6.68            2434
# 0                             9.64            5.75             352
# 26                            8.86            4.19            2120
#
#     Kasus AIDS 2024  Rasio HIV AIDS
# 14             3713        2.817129
# 11             3239        3.054338
# 12             2058        3.008260
# 1              1316        2.469605
# 18              465        2.698925
# 5               332        2.969880
# 7               351        3.475783
# 15              711        3.423347
# 0               130        2.707692
# 26              741        2.860999

# %%
df_merge.sort_values("Rata-rata Lama Sekolah (Tahun)", ascending=True).head(10)
# Out:
#                Provinsi  Jumlah penduduk miskin (Ribu)  \
# 37     PAPUA PEGUNUNGAN                         331.12
# 36         PAPUA TENGAH                         287.54
# 19     KALIMANTAN BARAT                         333.99
# 32          PAPUA BARAT                         108.28
# 17  NUSA TENGGARA BARAT                         658.60
# 12          JAWA TENGAH                        3396.34
# 18  NUSA TENGGARA TIMUR                        1107.94
# 29       SULAWESI BARAT                         155.91
# 14           JAWA TIMUR                        3893.82
# 28            GORONTALO                         170.03
#
#     Rata-rata Lama Sekolah (Tahun)  Indeks TPT (%)  Kasus HIV 2024  \
# 37                            4.21            1.32             559
# 36                            6.12            2.75            1311
# 19                            7.78            4.86            1309
# 32                            7.86            4.13             827
# 17                            7.87            2.73             627
# 12                            8.02            4.78            6191
# 18                            8.02            3.02            1255
# 29                            8.15            2.68             134
# 14                            8.28            4.19           10460
# 28                            8.29            3.13             277
#
#     Kasus AIDS 2024  Rasio HIV AIDS
# 37                0        0.000000
# 36              433        3.027714
# 19              415        3.154217
# 32              184        4.494565
# 17              189        3.317460
# 12             2058        3.008260
# 18              465        2.698925
# 29               56        2.392857
# 14             3713        2.817129
# 28               90        3.077778

# %%
df_merge.sort_values("Indeks TPT (%)", ascending=False).head(10)
# Out:
#             Provinsi  Jumlah penduduk miskin (Ribu)  \
# 11        JAWA BARAT                        3668.35
# 15            BANTEN                         777.49
# 34             PAPUA                         161.07
# 33  PAPUA BARAT DAYA                          96.81
# 9     KEPULAUAN RIAU                         124.96
# 10       DKI JAKARTA                         449.07
# 30            MALUKU                         293.99
# 24    SULAWESI UTARA                         173.30
# 2     SUMATERA BARAT                         315.43
# 0               ACEH                         718.96
#
#     Rata-rata Lama Sekolah (Tahun)  Indeks TPT (%)  Kasus HIV 2024  \
# 11                            8.87            6.75            9893
# 15                            9.23            6.68            2434
# 34                            9.82            6.48            2275
# 33                            8.39            6.48             291
# 9                            10.50            6.39             949
# 10                           11.49            6.21            5027
# 30                           10.26            6.11             861
# 24                            9.84            5.85             869
# 2                             9.44            5.75             654
# 0                             9.64            5.75             352
#
#     Kasus AIDS 2024  Rasio HIV AIDS
# 11             3239        3.054338
# 15              711        3.423347
# 34              819        2.777778
# 33               97        3.000000
# 9               352        2.696023
# 10             1820        2.762088
# 30              189        4.555556
# 24              312        2.785256
# 2               238        2.747899
# 0               130        2.707692

# %%
df_merge.sort_values("Rasio HIV AIDS", ascending=False).head(10)
# Out:
#                      Provinsi  Jumlah penduduk miskin (Ribu)  \
# 30                     MALUKU                         293.99
# 32                PAPUA BARAT                         108.28
# 13              DI YOGYAKARTA                         430.47
# 22           KALIMANTAN TIMUR                         211.88
# 7                     LAMPUNG                         939.30
# 15                     BANTEN                         777.49
# 4                       JAMBI                         272.70
# 17        NUSA TENGGARA BARAT                         658.60
# 8   KEPULAUAN BANGKA BELITUNG                          78.58
# 27          SULAWESI TENGGARA                         305.27
#
#     Rata-rata Lama Sekolah (Tahun)  Indeks TPT (%)  Kasus HIV 2024  \
# 30                           10.26            6.11             861
# 32                            7.86            4.13             827
# 13                            9.92            3.48             928
# 22                           10.02            5.14            1375
# 7                             8.36            4.19            1220
# 15                            9.23            6.68            2434
# 4                             8.90            4.48             313
# 17                            7.87            2.73             627
# 8                             8.33            4.63             277
# 27                            9.42            3.09             646
#
#     Kasus AIDS 2024  Rasio HIV AIDS
# 30              189        4.555556
# 32              184        4.494565
# 13              250        3.712000
# 22              389        3.534704
# 7               351        3.475783
# 15              711        3.423347
# 4                93        3.365591
# 17              189        3.317460
# 8                84        3.297619
# 27              196        3.295918
